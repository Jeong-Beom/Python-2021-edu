# %%
# (파이썬 코딩도장) Unit 22. 리스트와 튜플 응용하기
'''
x, y = map(int, input().split())
sol = []
for i in range(x, y+1):
    sol.append(2**i)
del sol[1], sol[-2]
print(sol)
'''

# (파이썬 코딩도장) Unit 23. 2차원 리스트 사용하기
'''
row, col = map(int, input().split())
matrix = list()
matrix.append(['NA']*(col+2))
for i in range(row):
    x_row = ['NA']
    x_row.extend(list(input().split()))
    x_row.append('NA')
    matrix.append(x_row)
matrix.append(['NA']*(col+2))

for i in range(row+2):
    for k in range(col+2):
        if matrix[i][k] != 'NA' and matrix[i][k] != '*':
            matrix[i][k] = 0
            boom = 0
            for x in range(i-1, i+2):
                for y in range(k-1, k+2):
                    if matrix[x][y] == '*' and matrix[x][y] != matrix[i][k]:
                        boom += 1
                        matrix[i][k] = boom
for i in range(1, row+1):
    for k in range(1, col+1):
        print(matrix[i][k], end = ' ')
    print()
for i in range(row+2):
    for k in range(col+2):
        print(matrix[i][k], end = ' ')
    print()
'''

# (파이썬 코딩도장) Unit 24. 문자열 응용하기
'''
input_value = 'the grown-\nups\' response, this time, was to advise me to lay asid my drawings of boa\n constrictors, whether \
from the inside or the outside, and devote myself i\nnstead to geography, history, arithmetic, and grammar. That \
is why at the\n, age of six, I gave up what might have been a magnificent career as a pai/nter. I had been disheartened \
by the failure of my Drawing Number One and \nmy Drawing Number Two. Grown-\nups never understand anything by themselves, and it is\
tiresome for childr\nen to be always and forever explaining things to the.'
value_change = list(input_value.split())
print(len(value_change))
import string
num = 0
for i in range(97):
    value_change[i] = value_change[i].strip(string.punctuation)
    if value_change[i] == 'the':
        num += 1
print(num, value_change.count('the'))
'''

# price_list = list(map(int, input().split(';')))
'''
price_list = [51900, 83000, 158000, 367500, 250000, 59200, 128500, 1304000]
price_list_changed = sorted(price_list, reverse = True)
for i in range(len(price_list_changed)):
    print(str(format(price_list_changed[i], ',')).rjust(9), end = '\n')
'''
# (파이썬 코딩도장) Unit 25. 딕셔너리 응용하기
'''
keys = ['alpha', 'bravo', 'charlie', 'delta', 'echo', 'foxtrot', 'golf']
values = [30, 40, 50, 60, 70, 80, 90]
 
x = dict(zip(keys, values))
del x['delta'], x['alpha']
x
'''

# (파이썬 코딩도장) Unit 27. 세트 사용하기
'''
a, b = map(int, input().split())
a1 = set(); b1 = set()
for i in range(1, a+1):
    if a % i == 0:
        a1.add(i)
for k in range(1, b+1):
    if b % k == 0:
        b1.add(k) 
print(a1, b1)
divisor = a1 & b1
 
result = 0
if type(divisor) == set:
    result = sum(divisor)
 
print(result)
'''
# Out:
# {1, 2, 4, 5, 100, 10, 50, 20, 25} {1, 2, 4, 5, 100, 8, 40, 10, 200, 50, 20, 25}
# 217
